# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Perceptron

# %%
df = pd.read_csv(r"G:\Python Projects,Docs\Machine learning\DL\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df.drop(columns=["Name","Sex","Ticket","Cabin","Embarked"])

# %%
df1.corrwith(df["Survived"])
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# dtype: float64

# %%
df2 = df1.drop(columns=["PassengerId","Age","Parch","SibSp"])

# %%
x = df2.drop(columns="Survived")
y = df2.Survived

# %%
x=x.fillna(0)
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
p_model = Perceptron()

# %%
p_model.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
p_model.coef_    #the weights of the inputs in the perceptron
# Out:
# array([[-135.    ,   17.7368]])

# %%
p_model.intercept_    #the bias of the perceptron
# Out:
# array([-56.])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(p_model.predict(x_test),y_test)
# Out:
# 0.7094972067039106
